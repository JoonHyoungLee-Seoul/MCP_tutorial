# %%
import sys
from dotenv import load_dotenv
import os

project_root = '/Users/ijunhyeong/Desktop/mcp/langgraph-mcp-agents/lee_mcp_tutorial'
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    
    
    
os.chdir(project_root)

result = load_dotenv(override=True)
print(f"작업 디렉토리: {os.getcwd()}")
print(f".env 파일 로드: {'성공' if result else '실패'}")
# Out:
# 작업 디렉토리: /Users/ijunhyeong/Desktop/mcp/langgraph-mcp-agents/lee_mcp_tutorial
# .env 파일 로드: 성공

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient
from langchain_anthropic import ChatAnthropic
from langgraph.prebuilt import create_react_agent
from langgraph.checkpoint.memory import MemorySaver
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_core.runnables import RunnableConfig
from utils import astream_graph


model = ChatAnthropic(
    model_name="claude-3-7-sonnet-latest", temperature=0, max_tokens=20000
)

# 3 MCP server Integration
client = MultiServerMCPClient({
    "document-retriever": {
        "command": "/Users/ijunhyeong/Desktop/mcp/langgraph-mcp-agents/.venv/bin/python",
        "args": ["./mcp_server_rag.py"],
        "transport": "stdio",
    },
    "calculator": {
        "command": "/Users/ijunhyeong/Desktop/mcp/langgraph-mcp-agents/.venv/bin/python",
        "args": ["./mcp_server_calculator.py"],
        "transport": "stdio",
    },
    "code-executor": {
        "command": "/Users/ijunhyeong/Desktop/mcp/langgraph-mcp-agents/.venv/bin/python",
        "args": ["./mcp_server_code_executor.py"],
        "transport": "stdio",
    },
})

# MCP tool load
mcp_tools = await client.get_tools()

# TavilySearch load
tavily = TavilySearchResults(max_results=2, topic="news", days=2)

# tools integration
all_tools = mcp_tools + [tavily]

print(f"\n{'='*60}")
print(f"🎉 통합 완료! 사용 가능한 도구: {len(all_tools)}개")
print(f"{'='*60}\n")

for i, tool in enumerate(all_tools, 1):
    category = ""
    if tool.name == "retrieve":
        category = "📚 Document"
    elif tool.name in ["calculate", "percentage_change", "statistics_summary", "currency_convert", "compare_values"]:
        category = "🧮 Calculator"
    elif tool.name in ["execute_python", "create_visualization", "analyze_data", "read_csv", "save_to_csv"]:
        category = "💻 Code Executor"
    elif tool.name == "tavily_search_results_json":
        category = "🔍 Web Search"
        
    print(f"{i:2d}. {category:20s} {tool.name}")

print(f"\n{'='*60}\n")

# Create the agent with new API
agent = create_react_agent(
    model,
    all_tools,
    prompt="""You are a powerful AI agent with multiple capabilities:

    📚 Document Retrieval (retrieve):
       - Search information from iPhone technical documents

    🧮 Calculator (calculate, percentage_change, statistics_summary, currency_convert, compare_values):
       - Perform mathematical calculations and statistical analysis

    💻 Code Executor (execute_python, create_visualization, analyze_data, read_csv, save_to_csv):
       - Execute Python code for data analysis
       - Create visualizations (charts, graphs)
       - Process and save data files

    🔍 Web Search (tavily_search_results_json):
       - Search latest news and web information

    Choose the most appropriate tools based on the user's request.
    You can use multiple tools in sequence for complex tasks.
    Always explain which tools you're using and why.""",
    checkpointer=MemorySaver()
)

# 설정
config = RunnableConfig(recursion_limit=30, thread_id=1)

print("✅ Agent created successfully!")
# Out:
# ============================================================
# 🎉 통합 완료! 사용 가능한 도구: 12개
# ============================================================
#
#  1. 📚 Document           retrieve
#  2. 🧮 Calculator         calculate
#  3. 🧮 Calculator         percentage_change
#  4. 🧮 Calculator         statistics_summary
#  5. 🧮 Calculator         currency_convert
#  6. 🧮 Calculator         compare_values
#  7. 💻 Code Executor      execute_python
#  8. 💻 Code Executor      create_visualization
#  9. 💻 Code Executor      analyze_data
# 10. 💻 Code Executor      read_csv
# 11. 💻 Code Executor      save_to_csv
# 12. 🔍 Web Search         tavily_search_results_json
#
# ============================================================
#
# ✅ Agent created successfully!
# /var/folders/jj/9j_fmr5d7993hd80n8v4stn80000gn/T/ipykernel_54486/3962062005.py:62: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(

# %% [markdown]
# ## Test 1: simple visualization

# %%
await astream_graph(
    agent,
    {
        "messages": """
        Create a bar chart showing iPhone sales:
        - iPhone 17 Pro: 2.8 million
        - iPhone 17: 3.5 million
        - iPhone 16 Pro: 2.5 million
        - iPhone 16: 3.2 million

        Title: "iPhone Sales Comparison (Q3 2025)"
        Save as: sales_comparison.png
        """
    },
    config=config
)
# Out:
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# I'll create a bar chart showing the iPhone sales data you provided. I'll use the `create_visualization` tool for this task.
# 🔧 Tool Selected: create_visualization
#
# 🔧 Tool Selected:
#
# 🔧 Tool Selected:
#
# 🔧 Tool Selected:
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ✅ Tool Executed: create_visualization
# Visualization created successfully!
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Chart Type:     bar
# Title:          iPhone Sales Comparison (Q3 2025)
# Filename:       sales_comparison.png
# Location:       /Users/ijunhyeong/Desktop/mcp/langgraph-mcp-agents/lee_mcp_tutorial/./output/sales_comparison.png
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# I've created a bar chart with the iPhone sales data you provided. The chart shows:
#
# - iPhone 17 Pro: 2.8 million units
# - iPhone 17: 3.5 million units (highest sales)
# - iPhone 16 Pro: 2.5 million units (lowest sales)
# - iPhone 16: 3.2 million units
#
# The chart has been titled "iPhone Sales Comparison (Q3 2025)" as requested and saved as "sales_comparison.png". The x-axis is labeled "iPhone Model" and the y-axis is labeled "Sales (millions)" for clarity.
#
# The visualization clearly shows that the iPhone 17 has the highest sales at 3.5 million units, followed by the iPhone 16 at 3.2 million units. The Pro models have slightly lower sales compared to their standard counterparts.
# {'node': 'agent',
#  'content': AIMessageChunk(content=[], additional_kwargs={}, response_metadata={'stop_reason': 'end_turn', 'stop_sequence': None, 'model_provider': 'anthropic'}, id='lc_run--9f614a71-1fd3-4943-99c2-9c17201ecd4f', usage_metadata={'input_tokens': 3866, 'output_tokens': 195, 'total_tokens': 4061, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}, chunk_position='last'),
#  'metadata': {'thread_id': 1,
#   'langgraph_step': 3,
#   'langgraph_node': 'agent',
#   'langgraph_triggers': ('branch:to:agent',),
#   'langgraph_path': ('__pregel_pull', 'agent'),
#   'langgraph_checkpoint_ns': 'agent:36d1a6ac-4034-b46f-4ff6-dd11ced52913',
#   'checkpoint_ns': 'agent:36d1a6ac-4034-b46f-4ff6-dd11ced52913',
#   'ls_provider': 'anthropic',
#   'ls_model_name': 'claude-3-7-sonnet-latest',
#   'ls_model_type': 'chat',
#   'ls_temperature': 0.0,
#   'ls_max_tokens': 20000,
#   'LANGSMITH_TRACING': 'true',
#   'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com',
#   'LANGSMITH_PROJECT': 'LangGraph-MCP-Agents',
#   'revision_id': 'Release-29-gd4694e9-dirty'}}

# %% [markdown]
# ## Test 2: Document Retrieve + Calculation

# %%
await astream_graph(
    agent,
    {
        "messages": """
        1. Use Document Retrieval to retrieve iPhone 17 Pro price from documents in euros.
        2. Use tavilysearch to check the currency between euro and Chinese RMB.
        2. Convert the euro price to RMB using the collected information.
        3. Show the result
        """
    },
    config=config
)
# Out:
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# I'll help you convert the iPhone 17 Pro price from euros to Chinese RMB following your step-by-step instructions.
#
# ### Step 1: Retrieve iPhone 17 Pro price from documents in euros
#
# First, let me search for the iPhone 17 Pro price in euros from the available documents.
# 🔧 Tool Selected: retrieve
#
# 🔧 Tool Selected:
#
# 🔧 Tool Selected:
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ✅ Tool Executed: retrieve
# iPhone 17 Pro Specifications
#
# Radio
# No
# USB
# USB Type-C 3.2 Gen 2, DisplayPort
# FEATURES
# Sensors
# Face ID, accelerometer, gyro, proximity, compass, barometer
#
# Ultra Wideband (UWB) support (gen2 chip)
# Emergency SOS, Messages and Find My via satellite
# BATTERY
# Type
# Li-Ion 3988 mAh - Nano SIM model
# Li-Ion 4252 mAh - eSIM only model
# Charging
# Wired, PD3.2, AVS, 50% in 20 min
# 25W wireless MagSafe/Qi2, 50% in 30 min (15W - China)
# 4.5W reverse wired
# MISC
# Colors
# Silver, Cosmic Orange, Deep Blue
# Models
# iPhone18,1, A3256, A3523, A3522, A3524
# Price
# £ 1,099.00 / € 1,299.00
# EU
# LABEL
# Energy
# Class A
# Battery
# 47:00h endurance, 1000 cycles
# Free fall
# Class B (180 falls)
# Repairability
# Class C
# iPhone 17 Pro Specifications
#
# NETWORK
# Technology
# GSM / CDMA / HSPA / EVDO / LTE / 5G
# LAUNCH
# Announced
# Release 2025, September 19
# Status
#
# BODY
# Dimensions
# 150 x 71.9 x 8.8 mm (5.91 x 2.83 x 0.35 in)
# Weight
# 206 g (7.27 oz)
# Build
# Glass front (Ceramic Shield 2), aluminum alloy frame, aluminum alloy back/ glass
# back (Ceramic Shield)
# SIM
# Nano-SIM + eSIM + eSIM (max 2 at a time; International)
# eSIM + eSIM (8 or more, max 2 at a time; USA)
# Nano-SIM + Nano-SIM (China)
#
# IP68 dust tight and water resistant (immersible up to 6m for 30 min)
# Apple Pay (Visa, MasterCard, AMEX certified)
# DISPLAY
# Type
# LTPO Super Retina XDR OLED, 120Hz, HDR10, Dolby Vision, 1000 nits (typ),
# 1600 nits (HBM), 3000 nits (peak)
# Size
# 6.3 inches, 96.4 cm2 (~89.4% screen-to-body ratio)
# Resolution
# 1206 x 2622 pixels, 19.5:9 ratio (~460 ppi density)
# Protection
# Ceramic Shield 2, Mohs level 5
#
# Anti-reflective coating
# PLATFORM
# OS
# iOS 26
# Chipset
# Apple A19 Pro (3 nm)
# CPU
# https://www.apple.com/iphone-17-pro/specs/?utm_source=chatgpt.com
# 15/17
# iPhone 17 - Technical Specifications - Apple
# https://www.apple.com/iphone-17/specs/?utm_source=chatgpt.com
# 7/15
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Perfect! I found the iPhone 17 Pro price in euros from the document: **€1,299.00**.
#
# ### Step 2: Check the exchange rate between euro and Chinese RMB
#
# Now, let me search for the current exchange rate between euro and Chinese RMB:
# 🔧 Tool Selected: tavily_search_results_json
#
# 🔧 Tool Selected:
#
# 🔧 Tool Selected:
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ✅ Tool Executed: tavily_search_results_json
# [{"title": "Euro to Chinese yuan rmb Exchange Rate History - Wise", "url": "https://wise.com/gb/currency-converter/eur-to-cny-rate/history", "content": "The exchange rate for Euro to Chinese yuan rmb is currently 8.27321 today, reflecting a -0.411% change since yesterday. Over the past week, the value of Euro has remained relatively stable, with a 0.322% decrease compared to its value 7 days ago.\n\nDuring the past week, the exchange rate of Euro to Chinese yuan rmb has fluctuated between a high of 8.34739 on 17-10-2025 and a low of 8.24665 on 14-10-2025. The largest 24-hour price movement occurred on 19-10-2025, with a 0.167% decrease in value.", "score": 0.9534532}, {"title": "1 EUR to CNY - Euros to Chinese Yuan Renminbi Exchange Rate - Xe", "url": "https://www.xe.com/en-us/currencyconverter/convert/?Amount=1&From=EUR&To=CNY", "content": "| cny Chinese Yuan RenminbiCNY | eur EuroEUR |\n --- |\n| 1 CNY | 0.120876 EUR |\n| 5 CNY | 0.604381 EUR |\n| 10 CNY | 1.20876 EUR |\n| 25 CNY | 3.02191 EUR |\n| 50 CNY | 6.04381 EUR |\n| 100 CNY | 12.0876 EUR |\n| 500 CNY | 60.4381 EUR |\n| 1,000 CNY | 120.876 EUR |\n| 5,000 CNY | 604.381 EUR |\n| 10,000 CNY | 1,208.76 EUR |\n\ncny\neur\n\n## EUR to CNY chart\n\n## EUR to CNY Chart\n\n1 EUR = 0 CNY\n\n1 EUR to CNY exchange-rate stats: high, low, average, and volatility over the last 7, 30, and 90 days. [...] # 1 EUR to CNY - Convert Euros to Chinese Yuan Renminbi\n\nXe Currency Converter\n\neur\ncny\n\n1.00 Euro =\n\n8.2729256 Chinese Yuan Renminbi\n\n1 CNY = 0.120876 EUR\n\n### Looking to make large transfers?\n\nWe can beat competitor rates\n\nWe use the mid-market rate for our Converter. This is for informational purposes only. You won’t receive this rate when sending money. Login to view send rates\n\nLight up their Diwali\n\nSend money home with Xe\n\n#### Convert Euro to Chinese Yuan Renminbi [...] Rate information of EUR/CNY currency pair\n\n| eur EuroEUR | cny Chinese Yuan RenminbiCNY |\n --- |\n| 1 EUR | 8.27293 CNY |\n| 5 EUR | 41.3646 CNY |\n| 10 EUR | 82.7293 CNY |\n| 25 EUR | 206.823 CNY |\n| 50 EUR | 413.646 CNY |\n| 100 EUR | 827.293 CNY |\n| 500 EUR | 4,136.46 CNY |\n| 1,000 EUR | 8,272.93 CNY |\n| 5,000 EUR | 41,364.6 CNY |\n| 10,000 EUR | 82,729.3 CNY |\n\neur\ncny\n\n#### Convert Chinese Yuan Renminbi to Euro\n\nRate information of CNY/EUR currency pair", "score": 0.88822687}]
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Based on the search results, I can see that the current exchange rate is approximately 8.27293 Chinese Yuan (RMB) to 1 Euro.
#
# ### Step 3: Convert the euro price to RMB
#
# Now I'll use the currency conversion tool to convert the iPhone 17 Pro price from euros to RMB:
# 🔧 Tool Selected: currency_convert
#
# 🔧 Tool Selected:
#
# 🔧 Tool Selected:
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ✅ Tool Executed: currency_convert
# Currency Conversion:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Amount:         1,299.00 EUR
# Exchange Rate:  1 EUR = 8.2729 RMB
# Result:         10,746.54 RMB
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ### Step 4: Show the result
#
# Here's the complete result of my analysis:
#
# **iPhone 17 Pro Price Conversion from Euros to RMB:**
#
# 1. **iPhone 17 Pro price in euros**: €1,299.00
# 2. **Current EUR to RMB exchange rate**: 1 EUR = 8.27293 RMB
# 3. **iPhone 17 Pro price in RMB**: ¥10,746.54
#
# Therefore, if you were to purchase an iPhone 17 Pro in China based on the European price converted to Chinese currency, it would cost approximately ¥10,746.54 based on the current exchange rate.
# {'node': 'agent',
#  'content': AIMessageChunk(content=[], additional_kwargs={}, response_metadata={'stop_reason': 'end_turn', 'stop_sequence': None, 'model_provider': 'anthropic'}, id='lc_run--2fbf9748-bfd8-4c54-ac11-ab3c77943113', usage_metadata={'input_tokens': 11042, 'output_tokens': 155, 'total_tokens': 11197, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}, chunk_position='last'),
#  'metadata': {'thread_id': 1,
#   'langgraph_step': 22,
#   'langgraph_node': 'agent',
#   'langgraph_triggers': ('branch:to:agent',),
#   'langgraph_path': ('__pregel_pull', 'agent'),
#   'langgraph_checkpoint_ns': 'agent:be852cd7-e302-0eea-956a-a8f790bc4b88',
#   'checkpoint_ns': 'agent:be852cd7-e302-0eea-956a-a8f790bc4b88',
#   'ls_provider': 'anthropic',
#   'ls_model_name': 'claude-3-7-sonnet-latest',
#   'ls_model_type': 'chat',
#   'ls_temperature': 0.0,
#   'ls_max_tokens': 20000,
#   'LANGSMITH_TRACING': 'true',
#   'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com',
#   'LANGSMITH_PROJECT': 'LangGraph-MCP-Agents',
#   'revision_id': 'Release-29-gd4694e9-dirty'}}

# %%
await astream_graph(
    agent,
    {
        "messages": """
        Complete analysis task:

        Step 1: Use Document Retrieval to retrieve iPhone 17 and iPhone 16 battery capacity from documents
        Step 2: Calculate the percentage difference
        Step 3: Search for battery life comparison reviews on the web
        Step 4: Create a comparison chart showing:
           - Battery capacity (mAh)
           - Percentage difference
        Step 5: Save the data to battery_comparison.csv
        
        """
    },
    config=config
)
# Out:
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# I'll complete this battery analysis task step by step as requested.
#
# ### Step 1: Retrieve iPhone 17 and iPhone 16 battery capacity from documents
#
# First, let me retrieve the iPhone 17 battery capacity:
# 🔧 Tool Selected: retrieve
#
# 🔧 Tool Selected:
#
# 🔧 Tool Selected:
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ✅ Tool Executed: retrieve
# iPhone 17 - Technical Specifications - Apple
# https://www.apple.com/iphone-17/specs/?utm_source=chatgpt.com
# 7/15
# iPhone 17 Pro Specifications
#
# Radio
# No
# USB
# USB Type-C 3.2 Gen 2, DisplayPort
# FEATURES
# Sensors
# Face ID, accelerometer, gyro, proximity, compass, barometer
#
# Ultra Wideband (UWB) support (gen2 chip)
# Emergency SOS, Messages and Find My via satellite
# BATTERY
# Type
# Li-Ion 3988 mAh - Nano SIM model
# Li-Ion 4252 mAh - eSIM only model
# Charging
# Wired, PD3.2, AVS, 50% in 20 min
# 25W wireless MagSafe/Qi2, 50% in 30 min (15W - China)
# 4.5W reverse wired
# MISC
# Colors
# Silver, Cosmic Orange, Deep Blue
# Models
# iPhone18,1, A3256, A3523, A3522, A3524
# Price
# £ 1,099.00 / € 1,299.00
# EU
# LABEL
# Energy
# Class A
# Battery
# 47:00h endurance, 1000 cycles
# Free fall
# Class B (180 falls)
# Repairability
# Class C
# https://www.apple.com/iphone-17-pro/specs/?utm_source=chatgpt.com
# 15/17
# iPhone 17 Pro Specifications
#
# NETWORK
# Technology
# GSM / CDMA / HSPA / EVDO / LTE / 5G
# LAUNCH
# Announced
# Release 2025, September 19
# Status
#
# BODY
# Dimensions
# 150 x 71.9 x 8.8 mm (5.91 x 2.83 x 0.35 in)
# Weight
# 206 g (7.27 oz)
# Build
# Glass front (Ceramic Shield 2), aluminum alloy frame, aluminum alloy back/ glass
# back (Ceramic Shield)
# SIM
# Nano-SIM + eSIM + eSIM (max 2 at a time; International)
# eSIM + eSIM (8 or more, max 2 at a time; USA)
# Nano-SIM + Nano-SIM (China)
#
# IP68 dust tight and water resistant (immersible up to 6m for 30 min)
# Apple Pay (Visa, MasterCard, AMEX certified)
# DISPLAY
# Type
# LTPO Super Retina XDR OLED, 120Hz, HDR10, Dolby Vision, 1000 nits (typ),
# 1600 nits (HBM), 3000 nits (peak)
# Size
# 6.3 inches, 96.4 cm2 (~89.4% screen-to-body ratio)
# Resolution
# 1206 x 2622 pixels, 19.5:9 ratio (~460 ppi density)
# Protection
# Ceramic Shield 2, Mohs level 5
#
# Anti-reflective coating
# PLATFORM
# OS
# iOS 26
# Chipset
# Apple A19 Pro (3 nm)
# CPU
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Now, let me retrieve the iPhone 16 battery capacity:
# 🔧 Tool Selected: retrieve
#
# 🔧 Tool Selected:
#
# 🔧 Tool Selected:
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ✅ Tool Executed: retrieve
# Energy
# 35% of manufacturing electricity for iPhone 17 is sourced from renewable electricity
# Exceeds U.S. Department of Energy requirements for battery charger systems
# Packaging
# 100% fiber-based packaging
# iPhone 17 packaging is designed to be more efficient than iPhone 16 boxes, enabling us to ship 35% more units
# per trip
# Waste
# No established final assembly sites generate waste sent to landfill as part of Apple’s Zero Waste Program
# Smarter chemistry
# All of the materials used in Apple products, accessories, and packaging are covered by the requirements of our
# Regulated Substances Specification, which was one of the first in industry to restrict the use of key substances of
# concern. See the latest Environmental Progress Report to understand Apple’s recent efforts in phasing out these
# chemistries.
# 22
# 23
# 24
# 25
# 26
# 27
# 28
# 29
# 25. 10. 20. 오후 2:14
# iPhone 17 - Technical Specifications - Apple
# https://www.apple.com/iphone-17/specs/?utm_source=chatgpt.com
# 12/15
# iPhone 17 - Technical Specifications - Apple
# https://www.apple.com/iphone-17/specs/?utm_source=chatgpt.com
# 7/15
# iPhone 17 Pro Specifications
#
# Radio
# No
# USB
# USB Type-C 3.2 Gen 2, DisplayPort
# FEATURES
# Sensors
# Face ID, accelerometer, gyro, proximity, compass, barometer
#
# Ultra Wideband (UWB) support (gen2 chip)
# Emergency SOS, Messages and Find My via satellite
# BATTERY
# Type
# Li-Ion 3988 mAh - Nano SIM model
# Li-Ion 4252 mAh - eSIM only model
# Charging
# Wired, PD3.2, AVS, 50% in 20 min
# 25W wireless MagSafe/Qi2, 50% in 30 min (15W - China)
# 4.5W reverse wired
# MISC
# Colors
# Silver, Cosmic Orange, Deep Blue
# Models
# iPhone18,1, A3256, A3523, A3522, A3524
# Price
# £ 1,099.00 / € 1,299.00
# EU
# LABEL
# Energy
# Class A
# Battery
# 47:00h endurance, 1000 cycles
# Free fall
# Class B (180 falls)
# Repairability
# Class C
# 2. Size and weight vary by configuration and manufacturing process.
# 3. iPhone 17 is splash, water, and dust resistant and was tested under controlled laboratory conditions with a rating of IP68 under IEC standard 60529 (maximum depth of 6
# meters up to 30 minutes). Splash, water, and dust resistance are not permanent conditions. Resistance might decrease as a result of normal wear. Do not attempt to
# charge a wet iPhone; refer to the user guide for cleaning and drying instructions. Liquid damage not covered under warranty.
# 4. Apple Intelligence is available in beta. Some features may not be available in all regions or languages. For feature and language availability and system requirements, see
# support.apple.com/121115.
# 5. All battery claims depend on network configuration and many other factors; actual results will vary. Battery has limited recharge cycles and may eventually need to be
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 await astream_graph(
#       2     agent,
#       3     {
#       4         "messages": """
#       5         Complete analysis task:
#       6
#       7         Step 1: Use Document Retrieval to retrieve iPhone 17 and iPhone 16 battery capacity from documents
#       8         Step 2: Calculate the percentage difference
#       9         Step 3: Search for battery life comparison reviews on the web
#      10         Step 4: Create a comparison chart showing:
#      11            - Battery capacity (mAh)
#      12            - Percentage difference
#      13         Step 5: Save the data to battery_comparison.csv
#      14
#      15         """
#      16     },
#      17     config=config
#      18 )
#
# File ~/Desktop/mcp/langgraph-mcp-agents/lee_mcp_tutorial/utils.py:71, in astream_graph(graph, inputs, config, node_names, callback, stream_mode, include_subgraphs)
#      68 prev_node = ""
#      70 if stream_mode == "messages":
# ---> 71     async for chunk_msg, metadata in graph.astream(
#      72         inputs, config, stream_mode=stream_mode
#      73     ):
#      74         curr_node = metadata["langgraph_node"]
#      75         final_result = {
#      76             "node": curr_node,
#      77             "content": chunk_msg,
#      78             "metadata": metadata,
#      79         }
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:3000, in Pregel.astream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2998 for task in await loop.amatch_cached_writes():
#    2999     loop.output_writes(task.id, task.writes, cached=True)
# -> 3000 async for _ in runner.atick(
#    3001     [t for t in loop.tasks.values() if not t.writes],
#    3002     timeout=self.step_timeout,
#    3003     get_waiter=get_waiter,
#    3004     schedule_task=loop.aaccept_push,
#    3005 ):
#    3006     # emit output
#    3007     for o in _output(
#    3008         stream_mode,
#    3009         print_mode,
#    (...)   3012         asyncio.QueueEmpty,
#    3013     ):
#    3014         yield o
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/langgraph/pregel/_runner.py:410, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     408 # panic on failure or timeout
#     409 try:
# --> 410     _panic_or_proceed(
#     411         futures.done.union(f for f, t in futures.items() if t is not None),
#     412         timeout_exc_cls=asyncio.TimeoutError,
#     413         panic=reraise,
#     414     )
#     415 except Exception as exc:
#     416     if tb := exc.__traceback__:
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/langgraph/pregel/_runner.py:520, in _panic_or_proceed(futs, timeout_exc_cls, panic)
#     518                 interrupts.append(exc)
#     519             elif fut not in SKIP_RERAISE_SET:
# --> 520                 raise exc
#     521 # raise combined interrupts
#     522 if interrupts:
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/langgraph/pregel/_retry.py:137, in arun_with_retry(task, retry_policy, stream, match_cached_writes, configurable)
#     135         break
#     136     else:
# --> 137         return await task.proc.ainvoke(task.input, config)
#     138 except ParentCommand as exc:
#     139     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:705, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     703     # run in context
#     704     with set_config_context(config, run) as context:
# --> 705         input = await asyncio.create_task(
#     706             step.ainvoke(input, config, **kwargs), context=context
#     707         )
#     708 else:
#     709     input = await step.ainvoke(input, config, **kwargs)
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:464, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     462         run = None
#     463     with set_config_context(child_config, run) as context:
# --> 464         ret = await asyncio.create_task(coro, context=context)
#     465 else:
#     466     ret = await coro
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/langgraph/prebuilt/chat_agent_executor.py:687, in create_react_agent.<locals>.acall_model(state, runtime, config)
#     685     response = cast(AIMessage, await dynamic_model.ainvoke(model_input, config))  # type: ignore[arg-type]
#     686 else:
# --> 687     response = cast(AIMessage, await static_model.ainvoke(model_input, config))  # type: ignore[union-attr]
#     689 # add agent name to the AIMessage
#     690 response.name = name
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3133, in RunnableSequence.ainvoke(self, input, config, **kwargs)
#    3131             else:
#    3132                 part = functools.partial(step.ainvoke, input_, config)
# -> 3133             input_ = await coro_with_context(part(), context, create_task=True)
#    3134     # finish the root run
#    3135 except BaseException as e:
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:5505, in RunnableBindingBase.ainvoke(self, input, config, **kwargs)
#    5498 @override
#    5499 async def ainvoke(
#    5500     self,
#    (...)   5503     **kwargs: Any | None,
#    5504 ) -> Output:
# -> 5505     return await self.bound.ainvoke(
#    5506         input,
#    5507         self._merge_configs(config),
#    5508         **{**self.kwargs, **kwargs},
#    5509     )
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.ainvoke(self, input, config, stop, **kwargs)
#     392 @override
#     393 async def ainvoke(
#     394     self,
#    (...)    399     **kwargs: Any,
#     400 ) -> AIMessage:
#     401     config = ensure_config(config)
# --> 402     llm_result = await self.agenerate_prompt(
#     403         [self._convert_input(input)],
#     404         stop=stop,
#     405         callbacks=config.get("callbacks"),
#     406         tags=config.get("tags"),
#     407         metadata=config.get("metadata"),
#     408         run_name=config.get("run_name"),
#     409         run_id=config.pop("run_id", None),
#     410         **kwargs,
#     411     )
#     412     return cast(
#     413         "AIMessage", cast("ChatGeneration", llm_result.generations[0][0]).message
#     414     )
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1099, in BaseChatModel.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1090 @override
#    1091 async def agenerate_prompt(
#    1092     self,
#    (...)   1096     **kwargs: Any,
#    1097 ) -> LLMResult:
#    1098     prompt_messages = [p.to_messages() for p in prompts]
# -> 1099     return await self.agenerate(
#    1100         prompt_messages, stop=stop, callbacks=callbacks, **kwargs
#    1101     )
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1057, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1044     if run_managers:
#    1045         await asyncio.gather(
#    1046             *[
#    1047                 run_manager.on_llm_end(
#    (...)   1055             ]
#    1056         )
# -> 1057     raise exceptions[0]
#    1058 flattened_outputs = [
#    1059     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[union-attr]
#    1060     for res in results
#    1061 ]
#    1062 llm_output = self._combine_llm_outputs([res.llm_output for res in results])  # type: ignore[union-attr]
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1267, in BaseChatModel._agenerate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1265 index = -1
#    1266 index_type = ""
# -> 1267 async for chunk in self._astream(messages, stop=stop, **kwargs):
#    1268     chunk.message.response_metadata = _gen_info_and_msg_metadata(chunk)
#    1269     if self.output_version == "v1":
#    1270         # Overwrite .content with .content_blocks
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/langchain_anthropic/chat_models.py:1775, in ChatAnthropic._astream(self, messages, stop, run_manager, stream_usage, **kwargs)
#    1773 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1774 try:
# -> 1775     stream = await self._acreate(payload)
#    1776     coerce_content_to_string = (
#    1777         not _tools_in_params(payload)
#    1778         and not _documents_in_params(payload)
#    1779         and not _thinking_in_params(payload)
#    1780     )
#    1781     block_start_event = None
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/langchain_anthropic/chat_models.py:1723, in ChatAnthropic._acreate(self, payload)
#    1721 if "betas" in payload:
#    1722     return await self._async_client.beta.messages.create(**payload)
# -> 1723 return await self._async_client.messages.create(**payload)
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/anthropic/resources/messages/messages.py:2107, in AsyncMessages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#    2100 if model in DEPRECATED_MODELS:
#    2101     warnings.warn(
#    2102         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#    2103         DeprecationWarning,
#    2104         stacklevel=3,
#    2105     )
# -> 2107 return await self._post(
#    2108     "/v1/messages",
#    2109     body=await async_maybe_transform(
#    2110         {
#    2111             "max_tokens": max_tokens,
#    2112             "messages": messages,
#    2113             "model": model,
#    2114             "metadata": metadata,
#    2115             "service_tier": service_tier,
#    2116             "stop_sequences": stop_sequences,
#    2117             "stream": stream,
#    2118             "system": system,
#    2119             "temperature": temperature,
#    2120             "thinking": thinking,
#    2121             "tool_choice": tool_choice,
#    2122             "tools": tools,
#    2123             "top_k": top_k,
#    2124             "top_p": top_p,
#    2125         },
#    2126         message_create_params.MessageCreateParamsStreaming
#    2127         if stream
#    2128         else message_create_params.MessageCreateParamsNonStreaming,
#    2129     ),
#    2130     options=make_request_options(
#    2131         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2132     ),
#    2133     cast_to=Message,
#    2134     stream=stream or False,
#    2135     stream_cls=AsyncStream[RawMessageStreamEvent],
#    2136 )
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1898, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1884 async def post(
#    1885     self,
#    1886     path: str,
#    (...)   1893     stream_cls: type[_AsyncStreamT] | None = None,
#    1894 ) -> ResponseT | _AsyncStreamT:
#    1895     opts = FinalRequestOptions.construct(
#    1896         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1897     )
# -> 1898     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/Desktop/mcp/langgraph-mcp-agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1698, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1695             await err.response.aread()
#    1697         log.debug("Re-raising status error")
# -> 1698         raise self._make_status_error_from_response(err.response) from None
#    1700     break
#    1702 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'This request would exceed the rate limit for your organization (0862ef1d-8a76-46e3-88d6-4cc8c7a3a6b9) of 20,000 input tokens per minute. For details, refer to: https://docs.claude.com/en/api/rate-limits. You can see the response headers for current usage. Please reduce the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}, 'request_id': 'req_011CUL4FCMPHHQkLZ1EZZCgY'}
# During task with name 'agent' and id '94ac721d-f585-85a5-c4d1-13d142fa5358'
